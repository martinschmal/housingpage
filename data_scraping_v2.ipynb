# %% [markdown]
# # Scrape data from craigslist

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup

import math
import re

# from IPython.display import display

pd.options.display.max_columns = None
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = 1000

# %% [markdown]
# ## Setup

# %%
url = 'https://berlin.craigslist.org/d/housing/search/hhh'

# %%
html = requests.get(url).content
bs = BeautifulSoup(html, "html.parser")
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    Berlin Immo  – craigslist
#   </title>
#   <meta content="Berlin Immo  – craigslist" name="description"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible">
#    <link href="https://berlin.craigslist.org/search/hhh" rel="canonical"/>
#    <link href="https://berlin.craigslist.org/search/hhh?format=rss" rel="alternate" title="RSS-Feed für craigslist | Berlin Immo  - craigslist" type="application/rss+xml"/>
#    <link href="https://berlin.craigslist.org/search/hhh?s=120" rel="next"/>
#    <meta content="width=device-width,initial-scale=1" name="viewport"/>
#    <link href="//www.craigslist.org/styles/cl.css?v=784f71fcd82733e2b32e8d3284beaf58" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/search.css?v=bc035cbbc3978b0ec9df93944cdf349b" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2" media="all" rel="stylesheet" type="text/css"/>
#    <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">
# <![endif]-->
#    <script type="text/javascript">
#     <!--
# var areaCountry = "DE";
# var areaID = "108";
# var areaRegion = "";
# var catAbb = "hhh";
# var countOfTotalText = "bild {count} von {total}";
# var currencySymbol = "&#x20AC;";
# var defaultView = "grid";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "Wng. Infos";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "kein bild";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = null;
# var searchDistance = null;
# var sectionAbb = "hhh";
# var sectionBase = "hhh";
# var showInfoText = "Zeige Infos";
# var showMapTabs = 0;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "Anzeige auf dem Merkzettel speichern";
# var subarea = null;
# var zoomToPosting = null;
# -->
#    </script>
#   </meta>
#  </head>
#  <body class="search">
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section class="page-container" id="page-top">
#    <div class="bglogo">
#    </div>
#    <div class="tryapp">
#     try the craigslist app »
#     <a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#      Android
#     </a>
#     <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#      iOS
#     </a>
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="/" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/hhh" class="breadcrumbs-form" data-action="/search/###/hhh" id="breadcrumbform" method="get">
#       <ul class="breadcrumbs">
#        <li class="crumb area">
#         <span class="no-js">
#          <a href="/">
#           Berlin
#          </a>
#         </span>
#         <select class="js-only" id="areaAbb" name="areaAbb">
#          <option value="berlin">
#           Berlin
#          </option>
#          <option value="bremen">
#           Bremen
#          </option>
#          <option value="dresden">
#           Dresden
#          </option>
#          <option value="hamburg">
#           Hamburg
#          </option>
#          <option value="hannover">
#           Hannover
#          </option>
#          <option value="copenhagen">
#           Kopenhagen
#          </option>
#          <option value="leipzig">
#           Leipzig
#          </option>
#          <option value="prague">
#           Prag
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb section">
#         <select id="catAbb" name="catAbb">
#          <option value="ggg">
#           Aushilfsjobs
#          </option>
#          <option value="ccc">
#           Community
#          </option>
#          <option value="bbb">
#           Dienstleistungen
#          </option>
#          <option value="eee">
#           Ereignisse
#          </option>
#          <option selected="" value="hhh">
#           Immo
#          </option>
#          <option value="jjj">
#           Jobs
#          </option>
#          <option value="rrr">
#           Lebensläufe
#          </option>
#          <option value="sss">
#           Zum Verkauf
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb category">
#         <select class="js-only" id="subcatAbb">
#          <option value="hhh">
#           Alles
#          </option>
#          <option value="off">
#           Büro &amp; Handel
#          </option>
#          <option value="vac">
#           Ferienwohnungen
#          </option>
#          <option value="rew">
#           Gesucht: Immobilie
#          </option>
#          <option value="sbw">
#           Gesucht: Untermiete / befristeter Wohnraum
#          </option>
#          <option value="hou">
#           Gesucht: Wohnungen
#          </option>
#          <option value="sha">
#           Gesucht: Zimmer / WG
#          </option>
#          <option value="reb">
#           Immobilien - vom Makler
#          </option>
#          <option value="reo">
#           Immobilien - von privat
#          </option>
#          <option value="swp">
#           Immobilientausch
#          </option>
#          <option value="prk">
#           Parken &amp; Lagerung
#          </option>
#          <option value="sub">
#           Untervermietungen &amp; Befristete Angebote
#          </option>
#          <option value="apa">
#           Wohnungen/Immo zur Miete
#          </option>
#          <option value="roo">
#           Zimmer &amp; Beteiligungen/WGs
#          </option>
#         </select>
#         <span class="no-js">
#          housing
#         </span>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb no-js">
#         <input type="submit" value="Los"/>
#        </li>
#       </ul>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/ber?lang=de">
#         Beitrag
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home?lang=de">
#         Konto
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           Favoriten
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <form action="/favorites" class="unfavform js-only" method="POST">
#         <div class="to-banish-page">
#          <input class="lastLink" name="lastLink" type="hidden" value="//berlin.craigslist.org/search/hhh"/>
#          <input class="lastTitle" name="lastTitle" type="hidden" value=""/>
#          <input class="unfaves" name="fl" type="hidden"/>
#          <input name="uf" type="hidden" value="1"/>
#          <a class="to-banish-page-link" href="#">
#           <span aria-hidden="true" class="icon icon-trash red">
#           </span>
#           <span class="banished_count">
#            0
#           </span>
#           <span class="discards-label">
#            Verborgen
#           </span>
#          </a>
#         </div>
#        </form>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <ul class="breadcrumbs">
#       Berlin            &gt;
#
# Immo
#      </ul>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <form action="/search/hhh" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="Suche aus">
#        «
#       </span>
#       <span class="search-closed" title="Suche ein">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="Immo durchsuchen" type="text" value=""/>
#      <button class="searchbtn" type="submit">
#       <span aria-hidden="true" class="icon icon-search">
#       </span>
#       <span class="screen-reader-text">
#        press to search craigslist
#       </span>
#      </button>
#      <div class="savealert">
#       <a class="saveme" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fberlin%252Ecraigslist%252Eorg%252Fsearch%252Fhhh" title="Suche speichern">
#        Suche speichern
#       </a>
#      </div>
#     </div>
#     <div class="search-options-container">
#      <h2 class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       optionen
#       <span class="options-close">
#        ende
#       </span>
#      </h2>
#      <input id="excats" name="excats" type="hidden"/>
#      <div class="search-options">
#       <div class="searchgroup categories">
#        <div class="cattitle">
#         <a class="reset" href="/search/hhh" title="Alle Suchparameter löschen">
#          Immo
#         </a>
#        </div>
#        <ul class="maincats">
#         <li class="morecats js-only closed">
#          <span class="linklike closed">
#           <span class="plusminus">
#            +
#           </span>
#           12 Kategorien anzeigen
#          </span>
#          <span class="linklike open">
#           <span class="plusminus">
#            –
#           </span>
#           12 Kategorien ausbl.
#          </span>
#          <span class="count">
#          </span>
#         </li>
#        </ul>
#        <ul class="othercats closed">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="off" id="cat_off" name="cat_id" type="checkbox" value="40"/>
#          <a class="category" href="/search/off">
#           Büro &amp; Handel
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="vac" id="cat_vac" name="cat_id" type="checkbox" value="99"/>
#          <a class="category" href="/search/vac">
#           Ferienwohnungen
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rew" id="cat_rew" name="cat_id" type="checkbox" value="121"/>
#          <a class="category" href="/search/rew">
#           Gesucht: Immobilie
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sbw" id="cat_sbw" name="cat_id" type="checkbox" value="58"/>
#          <a class="category" href="/search/sbw">
#           Gesucht: Untermiete / befristeter Wohnraum
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="hou" id="cat_hou" name="cat_id" type="checkbox" value="2"/>
#          <a class="category" href="/search/hou">
#           Gesucht: Wohnungen
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sha" id="cat_sha" name="cat_id" type="checkbox" value="19"/>
#          <a class="category" href="/search/sha">
#           Gesucht: Zimmer / WG
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rea" id="cat_rea" name="cat_id" type="checkbox" value="143,144"/>
#          <a class="category" href="/search/rea">
#           Immobilien
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="swp" id="cat_swp" name="cat_id" type="checkbox" value="65"/>
#          <a class="category" href="/search/swp">
#           Immobilientausch
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="prk" id="cat_prk" name="cat_id" type="checkbox" value="41"/>
#          <a class="category" href="/search/prk">
#           Parken &amp; Lagerung
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sub" id="cat_sub" name="cat_id" type="checkbox" value="39"/>
#          <a class="category" href="/search/sub">
#           Untervermietungen &amp; Befristete Angebote
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="apa" id="cat_apa" name="cat_id" type="checkbox" value="1"/>
#          <a class="category" href="/search/apa">
#           Wohnungen/Immo zur Miete
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="roo" id="cat_roo" name="cat_id" type="checkbox" value="18"/>
#          <a class="category" href="/search/roo">
#           Zimmer &amp; Beteiligungen/WGs
#          </a>
#          <span class="count">
#          </span>
#         </li>
#         <li>
#          <div class="selectall js-only checked">
#           <label>
#            <input checked="checked" class="catcheck selectallcb" type="checkbox"/>
#            <span class="all linklike">
#             Alle wählen
#            </span>
#           </label>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <input name="userid" type="hidden" value="">
#        <div class="searchgroup">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input class="" name="srchType" type="checkbox" value="T"/>
#            Nur Suchtitel
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            hat Bild
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            Heute gepostet
#           </label>
#          </li>
#          <li>
#           <label class="bundleDuplicates">
#            <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            Duplikate bündeln
#           </label>
#          </li>
#          <li>
#           <label class="searchNearby">
#            <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            Nahe Regionen einschließen
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas">
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="522">
#             bremen
#             <small>
#              (brm)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="313">
#             cologne
#             <small>
#              (cgn)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="107">
#             copenhagen
#             <small>
#              (cop)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="521">
#             dresden
#             <small>
#              (drs)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="418">
#             dusseldorf
#             <small>
#              (dus)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="141">
#             frankfurt
#             <small>
#              (fra)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="140">
#             hamburg
#             <small>
#              (ham)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="417">
#             hannover
#             <small>
#              (haj)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="519">
#             heidelberg
#             <small>
#              (hdb)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="520">
#             leipzig
#             <small>
#              (lej)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="614">
#             nuremberg
#             <small>
#              (nue)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="138">
#             prague
#             <small>
#              (prg)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li>
#           <span class="nextNearbyZone linklike" data-zone="1">
#            + zeige
#            <span id="nearbyNumber">
#             12
#            </span>
#            weitere ...
#           </span>
#          </li>
#         </ul>
#        </div>
#        <div class="searchgroup minmax price">
#         <span class="searchfieldlabel">
#          Preis
#         </span>
#         <input class="flatinput min" name="min_price" placeholder="Min" title="ganze Zahl, keine Buchstaben oder Symbole" type="tel" value=""/>
#         <input class="flatinput max" name="max_price" placeholder="Max" title="ganze Zahl, keine Buchstaben oder Symbole" type="tel" value=""/>
#        </div>
#        <div class="searchgroup bed-bath-selects">
#         <span class="searchfieldlabel">
#          Zimmer
#         </span>
#         <select class="autosubmit" name="min_bedrooms">
#          <option value="">
#           Min
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#         -
#         <select class="autosubmit" name="max_bedrooms">
#          <option value="">
#           Max
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup bed-bath-selects">
#         <span class="searchfieldlabel">
#          Badezimmer
#         </span>
#         <select class="autosubmit" name="min_bathrooms">
#          <option value="">
#           Min
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#         -
#         <select class="autosubmit" name="max_bathrooms">
#          <option value="">
#           Max
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup minmax">
#         <span class="searchfieldlabel">
#          ft
#          <sup>
#           2
#          </sup>
#         </span>
#         <input class="flatinput min" name="minSqft" placeholder="Min" title="ganze Zahl, keine Buchstaben oder Symbole" type="tel" value=""/>
#         <input class="flatinput max" name="maxSqft" placeholder="Max" title="ganze Zahl, keine Buchstaben oder Symbole" type="tel" value=""/>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          verfügbarkeit
#         </span>
#         <select class="autosubmit" name="availabilityMode">
#          <option value="0">
#           alle daten
#          </option>
#          <option value="1">
#           in 30 tagen
#          </option>
#          <option value="2">
#           über 30 tage
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup">
#         <label class="pets_cat">
#          <input class="autosubmit" name="pets_cat" type="checkbox" value="1">
#           Katzen ok
#          </input>
#         </label>
#         <br/>
#         <label class="pets_dog">
#          <input class="autosubmit" name="pets_dog" type="checkbox" value="1">
#           Hunde ok
#          </input>
#         </label>
#         <br/>
#         <label class="is_furnished">
#          <input class="autosubmit" name="is_furnished" type="checkbox" value="1">
#           möbliert
#          </input>
#         </label>
#         <br/>
#         <label class="no_smoking">
#          <input class="autosubmit" name="no_smoking" type="checkbox" value="1">
#           Rauchfrei
#          </input>
#         </label>
#         <br/>
#         <label class="wheelchaccess">
#          <input class="autosubmit" name="wheelchaccess" type="checkbox" value="1">
#           wheelchair access
#          </input>
#         </label>
#         <br/>
#         <label class="ev_charging">
#          <input class="autosubmit" name="ev_charging" type="checkbox" value="1">
#           Elektroautos aufladen
#          </input>
#         </label>
#         <br/>
#        </div>
#        <div class="searchgroup">
#         <div class="search-attribute hide-list" data-attr="housing_type">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           Immobilienart
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_1" name="housing_type" type="checkbox" value="1">
#              Apartment
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_2" name="housing_type" type="checkbox" value="2">
#              Eigentumswohnung
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_3" name="housing_type" type="checkbox" value="3">
#              Ferienhaus/Landhaus
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_4" name="housing_type" type="checkbox" value="4">
#              Maisonette
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_5" name="housing_type" type="checkbox" value="5">
#              Wohnung
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_6" name="housing_type" type="checkbox" value="6">
#              Haus
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_7" name="housing_type" type="checkbox" value="7">
#              Einliegerwohnung
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_8" name="housing_type" type="checkbox" value="8">
#              Loft
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_9" name="housing_type" type="checkbox" value="9">
#              Reihenhaus
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_10" name="housing_type" type="checkbox" value="10">
#              vorangefertigtes Haus
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_11" name="housing_type" type="checkbox" value="11"/>
#             betreutes Wohnen
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_12" name="housing_type" type="checkbox" value="12"/>
#             Land
#            </label>
#           </li>
#           <li class="selectall js-only">
#            <span class="all">
#             Alle wählen
#            </span>
#            <span class="none">
#             Ausw. aufheben
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="laundry">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           Wäscherei
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_1" name="laundry" type="checkbox" value="1"/>
#             Waschmaschine/Trockner in Wohnung
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_4" name="laundry" type="checkbox" value="4"/>
#             Anschluss für Waschmaschine/Trockner vorhanden
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_2" name="laundry" type="checkbox" value="2"/>
#             Waschraum im Gebäude
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_3" name="laundry" type="checkbox" value="3"/>
#             Waschraum vorhanden
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_5" name="laundry" type="checkbox" value="5"/>
#             Kein Waschraum verfügbar
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="parking">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           Parkplatz
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_1" name="parking" type="checkbox" value="1"/>
#             Stellplatz
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_2" name="parking" type="checkbox" value="2"/>
#             Anbaugarage
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_3" name="parking" type="checkbox" value="3"/>
#             freistehende Garage
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_4" name="parking" type="checkbox" value="4"/>
#             Parkmöglichkeiten abseits der Straße
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_5" name="parking" type="checkbox" value="5"/>
#             Parkmöglichkeiten entlang der Straße
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_6" name="parking" type="checkbox" value="6"/>
#             Parkservice
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_7" name="parking" type="checkbox" value="7"/>
#             keine Parkmöglichkeiten
#            </label>
#           </li>
#           <li class="selectall js-only">
#            <span class="all">
#             Alle wählen
#            </span>
#            <span class="none">
#             Ausw. aufheben
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="searchgroup">
#         <div class="searchfieldlabel">
#          Tag der offenen Tür
#         </div>
#         <select class="autosubmit" id="sale_date" name="sale_date">
#          <option>
#           alle daten
#          </option>
#          <option value="2020-02-15">
#           feb 15 - heute
#          </option>
#          <option value="2020-02-16">
#           feb 16 - morgen
#          </option>
#          <option value="2020-02-17">
#           feb 17 - montag
#          </option>
#          <option value="2020-02-18">
#           feb 18 - dienstag
#          </option>
#          <option value="2020-02-19">
#           feb 19 - mittwoch
#          </option>
#          <option value="2020-02-20">
#           feb 20 - donnerstag
#          </option>
#          <option value="2020-02-21">
#           feb 21 - friday
#          </option>
#          <option value="2020-02-22">
#           feb 22 - samstag
#          </option>
#          <option value="2020-02-23">
#           feb 23 - sonntag
#          </option>
#          <option value="2020-02-24">
#           feb 24 - montag
#          </option>
#          <option value="2020-02-25">
#           feb 25 - dienstag
#          </option>
#          <option value="2020-02-26">
#           feb 26 - mittwoch
#          </option>
#          <option value="2020-02-27">
#           feb 27 - donnerstag
#          </option>
#          <option value="2020-02-28">
#           feb 28 - friday
#          </option>
#          <option value="2020-02-29">
#           feb 29 - samstag
#          </option>
#          <option value="2020-03-01">
#           mãr 1 - sonntag
#          </option>
#          <option value="2020-03-02">
#           mãr 2 - montag
#          </option>
#          <option value="2020-03-03">
#           mãr 3 - dienstag
#          </option>
#          <option value="2020-03-04">
#           mãr 4 - mittwoch
#          </option>
#          <option value="2020-03-05">
#           mãr 5 - donnerstag
#          </option>
#          <option value="2020-03-06">
#           mãr 6 - friday
#          </option>
#          <option value="2020-03-07">
#           mãr 7 - samstag
#          </option>
#          <option value="2020-03-08">
#           mãr 8 - sonntag
#          </option>
#          <option value="2020-03-09">
#           mãr 9 - montag
#          </option>
#          <option value="2020-03-10">
#           mãr 10 - dienstag
#          </option>
#          <option value="2020-03-11">
#           mãr 11 - mittwoch
#          </option>
#          <option value="2020-03-12">
#           mãr 12 - donnerstag
#          </option>
#          <option value="2020-03-13">
#           mãr 13 - friday
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup resetsearch">
#         <a class="reset linklike" href="/search/hhh" title="Alle Suchparameter löschen">
#          zurück
#         </a>
#         <button class="searchlink linklike" type="submit">
#          suche aktualis.
#         </button>
#        </div>
#        <aside class="tsb">
#         <ul>
#          <li>
#           <a href="https://www.craigslist.org/about/fair_housing?lang=de">
#            faires Wohnen
#           </a>
#           <li>
#            <a href="https://www.craigslist.org/about/scams?lang=de">
#             Betrug vermeiden
#            </a>
#           </li>
#          </li>
#         </ul>
#        </aside>
#       </input>
#      </div>
#     </div>
#     <div class="search-legend">
#      <div class="search-view js-only">
#       <div aria-expanded="false" aria-label="view options" class="dropdown dropdown-icons dropdown-arrows dropdown-view" role="toolbar">
#        <ul class="dropdown-list">
#         <li class="dropdown-item mode sel">
#          <button data-selection="list" id="listview" title="Ergebnisse in Liste zeigen">
#           <span class="view-list icon">
#           </span>
#           Liste
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="pic" id="picview" title="Ergebnisse in Liste mit Vorschaubildern zeigen">
#           <span class="view-thumb icon">
#           </span>
#           Vorschau
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="grid" id="gridview" title="Ergebnisse nebeneinander mit größeren Bildern zeigen">
#           <span class="view-gallery icon">
#           </span>
#           Galerie
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="search-sort">
#       <div aria-expanded="false" aria-label="sort options" class="dropdown dropdown-sort dropdown-arrows" data-default-sort="date" role="toolbar">
#        <ul class="dropdown-list">
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="upcoming" href="/search/hhh?sort=upcoming&amp;" title="Tage der offenen Tür">
#           anstehend
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="true" class="dropdown-item mode sel">
#          <a data-selection="date" href="/search/hhh?sort=date&amp;" title="Neueste Ergebnisse zuerst">
#           Neustes
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="priceasc" href="/search/hhh?sort=priceasc&amp;" title="Nach Preis sortieren (nierdig/hoch)">
#           Preis ↑
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="pricedsc" href="/search/hhh?sort=pricedsc&amp;" title="Nach Preis sortieren (hoch/niedrig)">
#           Preis ↓
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         <span class="displaycountShow">
#          ...
#         </span>
#         {total} Anzeigen werden angezeigt
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/hhh" title="Erste Seite">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="Erste Seite">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/hhh" title="Vorherige Seite">
#         &lt; Zurück
#        </a>
#        <span class="button prev" title="Vorherige Seite">
#         &lt; Zurück
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          711
#         </span>
#        </span>
#        <a class="button next" href="/search/hhh?s=120" title="Weiter">
#         Weiter &gt;
#        </a>
#        <span class="button next" title="Weiter">
#         Weiter &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <div class="content" id="sortable-results">
#      <section class="favlistsection">
#       <section class="favlistinfo">
#       </section>
#       <section class="banishlistinfo">
#       </section>
#      </section>
#      <div class="open-map-view-button">
#       <span>
#        in karte anzeigen
#       </span>
#      </div>
#      <div data-arealat="52.523300" data-arealon="13.412700" id="mapcontainer">
#       <div id="noresult-overlay">
#       </div>
#       <div id="noresult-text">
#        <span class="message">
#         Kartierbar. Obj. n. gefund.
#        </span>
#       </div>
#       <div class="loading" id="map">
#        <div class="close-full-screen-map-mode-button">
#         fullscreen-modus schließen
#        </div>
#        <div class="close-map-view-button">
#         schließen
#        </div>
#       </div>
#      </div>
#      <ul class="rows">
#       <li class="result-row" data-pid="7075804163" data-repost-of="7055227875">
#        <a class="result-image gallery" data-ids="1:00808_gN4yLg6eDWh,1:00Q0Q_h2jEni60goK,1:00s0s_4DM5Bw9Wr6M,1:00M0M_lTJmKOcw82K,1:00A0A_e5tXIX4gDoH,1:00J0J_cMYPvsoQfv,1:00o0o_jApHNGRZFfr,1:00N0N_ihBxMPBnBdj,1:00c0c_5c7nyKCPRJR" href="https://berlin.craigslist.org/apa/d/rooftop-studio-in-neuklln-near/7075804163.html">
#         <span class="result-price">
#          €500
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           post zu favoriten
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-02-15 17:09" title="Sa 15 Feb 17:09:47">
#          Feb 15
#         </time>
#         <a class="result-title hdrlnk" data-id="7075804163" href="https://berlin.craigslist.org/apa/d/rooftop-studio-in-neuklln-near/7075804163.html">
#          ROOFTOP STUDIO IN NEUKÖLLN NEAR VOLKSPARK HASENHEIDE AND RATHAUS NEUKÖ
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           €500
#          </span>
#          <span class="housing">
#           1br -
#                     52m
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (Boddinstrasse and Rathaus Neukoelln)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            Bild
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            dieses posting verbergen
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            wiederherstellen
#           </span>
#           <span class="restore-wide-text">
#            dieses posting wiederherstellen
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="7068725043" data-repost-of="6467438748">
#        <a class="result-image gallery" data-ids="1:00101_dvC2DdmGxbg,1:00y0y_4y1RiAN4wyf,1:00909_5KqWQC6qGYc,1:00l0l_iN3aU1jgnDw,1:00909_7ldF3BtoDPF,1:00A0A_9FpTEHdhruS,1:00606_a51yNvT9TFn,1:00B0B_fTDMdKhKw5I,1:00X0X_1Ko2RIjHHPQ,1:00p0p_8WfnvzTppIJ" href="https://berlin.craigslist.org/apa/d/studio-apartment-available-new/7068725043.html">
#         <span class="result-price">
#          €500
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           post zu favoriten
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-02-15 17:08" title="Sa 15 Feb 17:08:06">
#          Feb 15
#         </time>
#         <a class="result-title hdrlnk" data-id="7068725043" href="https://berlin.craigslist.org/apa/d/studio-apartment-available-new/7068725043.html">
#          (^Studio Apartment Available w/ New Appliances! Patio! Pets Allowed^)
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           €500
#          </span>
#          <span class="housing">
#           1br -
#                     53m
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (Mitte)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            Bild
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            dieses posting verbergen
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            wiederherstellen
#           </span>
#           <span class="restore-wide-text">
#            dieses posting wiederherstellen
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="7062094492">
#        <a class="result-image gallery" data-ids="1:00P0P_dyGp10XnUJn,1:00q0q_20LT4K41Vqp,1:00n0n_avk4tsxQnHf,1:00v0v_kdykZz6wj8U,1:00r0r_7gRHlXBvcHZ,1:00n0n_1MzrvguOiov,1:00G0G_7UWS5o4mYAm,1:00F0F_72weOugMb8m,1:00505_32NkEWpP6Tc" href="https://berlin.craigslist.org/sub/d/mblierte-4-zimmer-etage-nahe-bahnhof/7062094492.html">
#         <span class="result-price">
#          €1100
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           post zu favoriten
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-02-15 16:58" title="Sa 15 Feb 16:58:19">
#          Feb 15
#         </time>
#         <a class="result-title hdrlnk" data-id="7062094492" href="https://berlin.craigslist.org/sub/d/mblierte-4-zimmer-etage-nahe-bahnhof/7062094492.html">
#          Möblierte 4-Zimmer Etage nahe S-Bahnhof Hermsdorf
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           €1100
#          </span>
#          <span class="housing">
#           4br -
#                     113m
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            Bild
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            dieses posting verbergen
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            wiederherstellen
#           </span>
#           <span class="restore-wide-text">
#            dieses posting wiederherstellen
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="7068978712">
#        <a class="result-image gallery" data-ids="1:01212_hq8WuYd4Kmu" href="https://berlin.craigslist.org/apa/d/cosy-lavishly-equipped-studio-apartment/7068978712.html">
#         <span class="result-price">
#          €600
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           post zu favoriten
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-02-15 16:47" title="Sa 15 Feb 16:47:45">
#          Feb 15
# ...
#          Bright studio apartment for rent in Neukölln
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           €450
#          </span>
#          <span class="housing">
#           1br -
#                     40m
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (Berlin)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            Bild
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            dieses posting verbergen
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            wiederherstellen
#           </span>
#           <span class="restore-wide-text">
#            dieses posting wiederherstellen
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="7068731808">
#        <a class="result-image gallery" data-ids="1:00o0o_k6CfxsrWG1M,1:00F0F_50l5rWn5EhH,1:00B0B_79oeUIIaito,1:00p0p_5lGAB01Jrje,1:01414_18LTKTObXKb,1:00c0c_fBKfJdfnCM9,1:00N0N_cZ3MTp6mSaj,1:00C0C_6VQYKvMWKIX,1:00000_hNtiAi1dI1d,1:00505_emQUGAV7MTt" href="https://berlin.craigslist.org/apa/d/reserve-move-in-1br-aprt-for-rent/7068731808.html">
#         <span class="result-price">
#          €401
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           post zu favoriten
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-02-13 16:29" title="Do 13 Feb 16:29:11">
#          Feb 13
#         </time>
#         <a class="result-title hdrlnk" data-id="7068731808" href="https://berlin.craigslist.org/apa/d/reserve-move-in-1br-aprt-for-rent/7068731808.html">
#          RESERVE/MOVE IN! 1BR APRT FOR RENT
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           €401
#          </span>
#          <span class="result-hood">
#           (Mitte, Berlin)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            Bild
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            dieses posting verbergen
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            wiederherstellen
#           </span>
#           <span class="restore-wide-text">
#            dieses posting wiederherstellen
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="7071714684" data-repost-of="7069391285">
#        <a class="result-image gallery" data-ids="1:00303_9Togg9MKh85,1:00d0d_lvoZj5nqEsv,1:00I0I_E1jHD9aIZ4,1:00e0e_5VGq1SMu2ZY,1:00K0K_6d9uyrVXA8j,1:00S0S_hBQ2D0A0yW0,1:00W0W_1W4AEPNyXVo,1:00303_jyl7uLOsK9l,1:00C0C_2uJcyv2XEzi,1:00k0k_7MZ2wrXgJ8k,1:00s0s_gR1chnfRjMg,1:00i0i_gjLElac8yo3" href="https://berlin.craigslist.org/apa/d/book-1br-for-anytime-make-this-yours/7071714684.html">
#         <span class="result-price">
#          €499
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           post zu favoriten
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-02-13 16:28" title="Do 13 Feb 16:28:18">
#          Feb 13
#         </time>
#         <a class="result-title hdrlnk" data-id="7071714684" href="https://berlin.craigslist.org/apa/d/book-1br-for-anytime-make-this-yours/7071714684.html">
#          BOOK 1BR FOR ANYTIME! MAKE THIS YOURS TODAY!
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           €499
#          </span>
#          <span class="result-hood">
#           (Prenzlauer Berg, Berlin)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            Bild
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            dieses posting verbergen
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            wiederherstellen
#           </span>
#           <span class="restore-wide-text">
#            dieses posting wiederherstellen
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="7069399517" data-repost-of="6849633092">
#        <a class="result-image gallery" data-ids="1:00T0T_d5XYNvMaAKJ,1:00N0N_keatG4ChLbb,1:00Z0Z_9slIzLBqf5p,1:00j0j_kPwMjJrfXyO,1:00909_euUTvOLsq7Z,1:00F0F_gBBfDqc2eND,1:00606_1mxzjyjjsTj,1:00n0n_hktCyMY4Gtg,1:01212_7tQb60YJmsQ,1:00F0F_iWIP6JUR0Pb,1:01616_6fXHTLv8SPx" href="https://berlin.craigslist.org/apa/d/beautiful-studio-apartment/7069399517.html">
#         <span class="result-price">
#          €400
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           post zu favoriten
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-02-13 16:27" title="Do 13 Feb 16:27:53">
#          Feb 13
#         </time>
#         <a class="result-title hdrlnk" data-id="7069399517" href="https://berlin.craigslist.org/apa/d/beautiful-studio-apartment/7069399517.html">
#          BEAUTIFUL STUDIO APARTMENT
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           €400
#          </span>
#          <span class="result-hood">
#           (Prenzlauer Berg, Berlin)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            Bild
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            dieses posting verbergen
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            wiederherstellen
#           </span>
#           <span class="restore-wide-text">
#            dieses posting wiederherstellen
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#      </ul>
#     </div>
#     <div class="search-legend bottom">
#      <div class="search-view">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ Zurück
#        </a>
#       </span>
#      </div>
#      <div class="search-sort">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ Zurück
#        </a>
#       </span>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         <span class="displaycountShow">
#          ...
#         </span>
#         {total} Anzeigen werden angezeigt
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/hhh" title="Erste Seite">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="Erste Seite">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/hhh" title="Vorherige Seite">
#         &lt; Zurück
#        </a>
#        <span class="button prev" title="Vorherige Seite">
#         &lt; Zurück
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          711
#         </span>
#        </span>
#        <a class="button next" href="/search/hhh?s=120" title="Weiter">
#         Weiter &gt;
#        </a>
#        <span class="button next" title="Weiter">
#         Weiter &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <section class="blurbs">
#     </section>
#     <div id="floater">
#      <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
#      <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
#     </div>
#    </form>
#    <aside class="tsb">
#     <ul>
#      <li>
#       <a href="https://www.craigslist.org/about/fair_housing?lang=de">
#        faires Wohnen
#       </a>
#       <li>
#        <a href="https://www.craigslist.org/about/scams?lang=de">
#         Betrug vermeiden
#        </a>
#       </li>
#      </li>
#     </ul>
#    </aside>
#    <div class="slidemessage">
#     <span class="fave">
#      <span class="star">
#      </span>
#      favorisiert
#     </span>
#     <span class="unfave">
#      <span class="star">
#      </span>
#      nicht mehr favorisiert
#     </span>
#     <span class="hide">
#      <span class="trash">
#      </span>
#      Verborgen
#     </span>
#     <span class="unhide">
#      <span class="trash">
#      </span>
#      nicht länger verborgen
#     </span>
#    </div>
#    <footer>
#     <span class="rss">
#      <a class="l" href="https://berlin.craigslist.org/search/hhh?format=rss">
#       RSS
#      </a>
#      <a href="https://www.craigslist.org/about/rss?lang=de">
#       (?)
#      </a>
#      <br/>
#     </span>
#     <ul class="clfooter">
#      <li>
#       ©
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/?lang=de">
#        Hilfe
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams?lang=de">
#        Sicherheit
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy?lang=de">
#        Datenschutz
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        Feedback
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/craigslist_is_hiring?lang=de">
#        CL Jobs
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/terms.of.use.de-de">
#        Bedingungen
#       </a>
#       <sup class="neu">
#        Neu
#       </sup>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/?lang=de">
#        Impressum
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       Mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <template id="gallerycarousel">
#    <div class="slider-info">
#    </div>
#    <div class="slider-back arrow">
#     &lt;
#    </div>
#    <div class="slider-forward arrow">
#     &gt;
#    </div>
#   </template>
#   <script>
#    try {
#                     if (
#                         !/\/\/.+\.craigslist\.org\/about\//.test(window.location.href)
#                         &&
#                         (!window.addEventListener || JSON.parse(JSON.stringify('x')) !== 'x')
#                     ) {
#                         throw "unsupported browser";
#                     }
#                 } catch (e) {
#                     function cleanup() {
#                         document.body.innerHTML = '<div id="cl-unsupported-browser" style="margin:1em;font-size:150%;text-align:center;">We have detected you are using a browser that is missing critical features.<br><br>Please visit craigslist from a modern browser.</div>';
#                         document.body.style = "display:block";
#                     }
#
#                     try {
#                         document.body.style = "display:none";
#                     } catch (e) {
#                     }
#                     window.onload = cleanup;
#                     window.clUnsupportedBrowser = true;
#                 }
#   </script>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=52193b5fab7b153c780451e9f36c4337" type="text/javascript">
#   </script>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">dieses posting verbergen</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     einbl.
#                 </span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">post zu favoriten</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">dieses posting verbergen</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">einbl.</span>
#                         einbl.
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">Anz. zeigen</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">mehr Infos</a>
#             <a class="showpics">Bilder zeigen</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#   <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=80e2b848534ada75cc0b6a344987c14e" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/search-concat.min.js?v=ece21c8ea54216c17ff8cca2b77f0130" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/postings-concat.min.js?v=31acdacaf9a14387c585821a262e5913" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
rows = (bs.find('body')
 # .find('section', {'class':'page-container'})
 # .find('form', {'id':'searchform'})
 # .find('div', {'class':'content'})
        .find('ul', {'class':'rows'}))

# %% [markdown]
# ## Functions

# %% [markdown]
# #### Function `get_data_one_page`
# Crawls data from one page (usually 120 entries) and outputs a df

# %%
def get_data_one_page(rows):

    # define empty lists to be filled with crawled information
    lst_id = []
    lst_link = []
    lst_title = []
    lst_price = []
    lst_size = []
    lst_hood = []
    lst_date = []
    lst_img_link = []
    lst_desc = []
    lst_num_rooms = []

    for result in rows.find_all('li', {'class': 'result-row'}):
        
        # get information from overview page
        lst_id.append(result['data-pid']) if result['data-pid'] is not None else lst_id.append(np.NaN)
        lst_link.append(result.find('a', {'class': 'result-title hdrlnk'})['href']) if result.find('a', {'class': 'result-title hdrlnk'}) is not None else lst_link.append(np.NaN)
        lst_title.append(result.find('a', {'class': 'result-title hdrlnk'}).text) if result.find('a', {'class': 'result-title hdrlnk'}) is not None else lst_title.append(np.NaN)
        lst_price.append(result.find('span', {'class': 'result-price'}).text) if result.find('span', {'class': 'result-price'}) is not None else lst_price.append(np.NaN)
        lst_hood.append(result.find('span', {'class': 'result-hood'}).text) if result.find('span', {'class': 'result-hood'}) is not None else lst_hood.append(np.NaN)
        lst_date.append(result.find('time', {'class': 'result-date'})['datetime'])
        
        if result.find('span', {'class': 'housing'}) is not None:
            size = result.find('span', {'class': 'housing'}).text
            lst_size.append(int(re.findall(r"(\d+)m2", size)[0])) if len(re.findall(r"(\d+)m2", size)) >= 1 else lst_size.append(np.NaN)
            lst_num_rooms.append(int(re.findall(r"(\d+)br", size)[0])) if len(re.findall(r"(\d+)br", size)) >= 1 else lst_num_rooms.append(np.NaN)
        else:
            lst_size.append(np.NaN)
            lst_num_rooms.append(np.NaN)
            
        
        # get image link and description from detailed web page (not overview page)
        url = result.find('a', {'class': 'result-title hdrlnk'})['href']
        html = requests.get(url).content
        bs = BeautifulSoup(html, "html.parser")
        
        lst_img_link.append(bs.find('img', {'title': '1'})['src']) if bs.find('img', {'title': '1'}) is not None else lst_img_link.append(np.NaN)
        lst_desc.append(bs.find('section', {'id': 'postingbody'}).text.replace('\n', ' ').replace('QR Code Link to This Post', '').strip()) if bs.find('section', {'id': 'postingbody'}) is not None else lst_desc.append(np.NaN)    
        
        
    # define dict based on the crawled data to create the dataframe    
    di_results = {
        'id': lst_id,
        'title': lst_title,
        'price': lst_price,
        'size': lst_size,
        'rooms': lst_num_rooms,
        'hood': lst_hood,
        'date': lst_date,
        'description': lst_desc,
        'link': lst_link,
        'img_link': lst_img_link,
    }
    
    return pd.DataFrame(di_results)

# %% [markdown]
# #### Function `get_all_data`
# Loops over all search pages and calls `get_data_one_page` and outputs a df

# %%
def get_all_data(url_main):
    html = requests.get(url_main).content
    bs = BeautifulSoup(html, "html.parser")
    
    # calculate number of pages to loop over
    num_entries = int(bs.find('span', {'class': 'totalcount'}).text)
    to_range = int(bs.find('span', {'class': 'rangeTo'}).text)
    num_pages = math.floor(num_entries/to_range)
    
    # for each search page, retrieve information and append to a master df
    for num_page in range(num_pages+1):
        url = f'https://berlin.craigslist.org/d/housing/search/hhh?s={num_page*120}'
        html = requests.get(url).content
        bs = BeautifulSoup(html, "html.parser")
        rows = (bs.find('body').find('ul', {'class':'rows'}))
        try:
            df = df.append(get_data_one_page(rows), ignore_index=True)
        except:
            df = get_data_one_page(rows)
    
    return df

# %% [markdown]
# ## Crawl Data

# %%
# %time df_all = get_all_data(url)
# Out:
# CPU times: user 32.1 s, sys: 880 ms, total: 33 s
# Wall time: 5min 56s

# %% [markdown]
# ## Data Cleaning

# %%
df_output = df_all.copy()

# %% [markdown]
# #### Make neighborhood names consistent

# %%
df_output['hood'] = df_output['hood'].str.replace('(', '').str.replace(')', '')

# %%
# define dictionary

di_hoods = {
    'kreuzberg': 'Kreuzberg',
    'prenzlau': 'Prenzlauer Berg',
    'neuk': 'Neukölln',
    'mitte': 'Mitte',
    'friedrichsh': 'Friedrichshain'
}

# %%
for k, v in di_hoods.items():
    df_output['hood'] = np.where(df_output['hood'].str.contains(k, case=False), v, df_output['hood'])

# %% [markdown]
# #### Clean `price` column

# %%
df_output['price'] = df_output['price'].str.strip('€').astype(float)

# %%
# remove high prices (=outliers?!)

df_output = df_output[df_output['price'] < 5000]

# %%
# remove low prices (=outliers?!)

df_output = df_output[df_output['price'] >= 10]

# %% [markdown]
# ## Output JSON

# %%
df_output.head(3)
# Out:
#            id  \
# 0  7075804163
# 1  7068725043
# 2  7062094492
#
#                                                                     title  \
# 0  ROOFTOP STUDIO IN NEUKÖLLN NEAR VOLKSPARK HASENHEIDE AND RATHAUS NEUKÖ
# 1   (^Studio Apartment Available w/ New Appliances! Patio! Pets Allowed^)
# 2                       Möblierte 4-Zimmer Etage nahe S-Bahnhof Hermsdorf
#
#     price   size  rooms       hood              date  \
# 0   500.0   52.0    1.0   Neukölln  2020-02-15 17:09
# 1   500.0   53.0    1.0      Mitte  2020-02-15 17:08
# 2  1100.0  113.0    4.0  Kreuzberg  2020-02-15 16:58
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                description  \
# 0  App. 45 sqm (484 sf)  2 persons max. 5th floor (lift)  Fully Equipped Kitchen Digital TV Open Kitchen Balcony / Terrace Washing Machine Sofa Microwave Bed Linen & Towels Bathroom with Shower WIFI Connection Living Room Green View Queen Size Bed 1,60x2m The Apartment  This bright and cosy rooftop studio apartment is perfect for one person or a couple. There is a queen size bed, a big cupboard and a Sony Tv for home entertainment. The open plan kitchen is fully equipped including a microwave. Enjoy breakfast and meals at the dining table which can seat up to three persons or on the balcony. The bright bathroom has a shower and washing machine. The apartment can be reached comfortably by a lift  Location  The apartment is located in Neukoelln near Boddinstrasse and Rathaus Neukoelln. In this multicultural area you will find lots of students, clubs, cafes and loads of shops and diverse restaurants. Also the annual art festival 48 Stunden Neukoelln takes place every summer where hundred...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             The apartment is perfectly located on the well known Torstrasse strip in Berlin "Mitte". It's surrounded by restaurants, bars and galleries. Tram/subway station "Oranienburger Straße" is only a few hundred meters away and "Rosenthaler Platz" is easily reachable by foot. Main sights like the Brandenburger Gate, Reichstag, Wall Museum, Alexanderplatz etc. are as well located in walking distance.
# 2                                                                                                                                                                                                                                                                                              Möblierte 4-Zimmer Etage in Villensouterrain nahe S-Bahnhof Hermsdorf  Der Villenvorort Hermsdorf liegt im Berliner Norden zwischen Waidmannslust und Frohnau. Sehr ruhige bevorzugte Lage - 3 Gehminuten vom S-Bahnhof Hermsdorf und allen Einkaufmöglichkeiten entfernt, ca. 23 Minuten direkt zum Berliner Stadtzentrum / Brandenburger Tor ca. 10 Autominuten zum Flughafen Tegel. ca. 113 qm große Küche mit Herd, Kühlschrank und Waschmaschine, Duschbad mit WC, DSL Anschluss Die Räume sind komplett eingerichtet und ausgestattet.  Monatsmiete 1100,00 € kalt Nebenkosten Eigenverbrauch/Energie Kaution  Erstkontakt bitte AUSSCHLIESSLICH telefonisch von 10.00 bis 19.00 Uhr keine Mails / SMS Bitte keine Vermittleranfragen
#
#                                                                                        link  \
# 0        https://berlin.craigslist.org/apa/d/rooftop-studio-in-neuklln-near/7075804163.html
# 1        https://berlin.craigslist.org/apa/d/studio-apartment-available-new/7068725043.html
# 2  https://berlin.craigslist.org/sub/d/mblierte-4-zimmer-etage-nahe-bahnhof/7062094492.html
#
#                                                       img_link
# 0  https://images.craigslist.org/00808_gN4yLg6eDWh_600x450.jpg
# 1  https://images.craigslist.org/00101_dvC2DdmGxbg_600x450.jpg
# 2  https://images.craigslist.org/00P0P_dyGp10XnUJn_600x450.jpg

# %%
df_output.to_json('data_v3.json', orient='records')
